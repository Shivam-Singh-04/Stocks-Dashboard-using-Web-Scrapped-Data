# %%
#Installing the necessary libraries. you can uncomment for the first time.
#!pip install yfinance==0.1.67
#!mamba install bs4==4.10.0 -y
#!pip install nbformat==4.2.0

# %%
#Importing the necessary libraries
import yfinance as yf
import pandas as pd

# %%
#Downloading apple stock history data
apple_data = yf.download('AAPL')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
#View apple data
apple_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099058
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093890
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086999
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089152
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091737
# ...                ...         ...         ...         ...         ...
# 2024-05-07  183.449997  184.899994  181.320007  182.399994  182.152924
# 2024-05-08  182.850006  183.070007  181.449997  182.740005  182.492477
# 2024-05-09  182.559998  184.660004  182.110001  184.570007  184.320007
# 2024-05-10  184.899994  185.089996  182.130005  183.050003  183.050003
# 2024-05-13  185.440002  187.100006  184.619995  186.279999  186.279999
#
#                Volume
# Date
# 1980-12-12  469033600
# 1980-12-15  175884800
# 1980-12-16  105728000
# ...

# %%
#Since date is at the index column, we will reset the index
apple_data.reset_index(inplace=True)

# %%
#View the final data
apple_data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099058
# 1     1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093890
# 2     1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086999
# 3     1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089152
# 4     1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091737
# ...          ...         ...         ...         ...         ...         ...
# 10940 2024-05-07  183.449997  184.899994  181.320007  182.399994  182.152924
# 10941 2024-05-08  182.850006  183.070007  181.449997  182.740005  182.492477
# 10942 2024-05-09  182.559998  184.660004  182.110001  184.570007  184.320007
# 10943 2024-05-10  184.899994  185.089996  182.130005  183.050003  183.050003
# 10944 2024-05-13  185.440002  187.100006  184.619995  186.279999  186.279999
#
#           Volume
# 0      469033600
# ...

# %%
#Exportinf the dataframe in csv format
Apple_Stock_History = apple_data.to_csv('D:/SHIVAM/Imarticus-PGA/Self-Study (Extra)/Tableau/Stocks Dashboard using Web Scrapped Data/Apple_Stock_History.csv')
